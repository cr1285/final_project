# %%
#load data
import yaml
import pandas as pd

with open('raw_data/legislators-social-media.yaml') as f:
    data = yaml.safe_load(f)

# Convert nested YAML objects into a flat DataFrame
df_rep_media = pd.json_normalize(data)

df_rep_media.head()
# Out:
#   id.bioguide id.thomas  id.govtrack   social.twitter    social.facebook  \
# 0     R000600     02222     412664.0         RepAmata         aumuaamata
# 1     Y000064     02019     412428.0     SenToddYoung   SenatorToddYoung
# 2     E000295     02283     412667.0     SenJoniErnst       senjoniernst
# 3     T000476     02291     412668.0    SenThomTillis  SenatorThomTillis
# 4     W000809     01991     412402.0  Rep_SteveWomack     RepSteveWomack
#
#           social.youtube_id  social.twitter_id     social.youtube  \
# 0  UCGdrLQbt1PYDTPsampx4t1A       3.026623e+09                NaN
# 1  UCuknj4PGn91gHDNAfboZEgQ       2.341285e+08       RepToddYoung
# 2  UCLwrmtF_84FIcK3TyMs4MIw       2.856788e+09                NaN
# 3  UCUD9VGV4SSGWjGdbn37Ea2w       2.964175e+09                NaN
# 4  UCXJbUDLYX-wGIhRuN66hqZw       2.344693e+08  CongressmanWomack
#
#   social.instagram  social.instagram_id social.mastodon
# 0              NaN                  NaN             NaN
# 1     sentoddyoung                  NaN             NaN
# 2     senjoniernst         1.582703e+09             NaN
# 3    senthomtillis                  NaN             NaN
# 4  rep_stevewomack                  NaN             NaN

# %%
from datetime import datetime

#load data with representative names and bioguide numbers

with open("raw_data/legislators-current.yaml") as f:
    legislators = yaml.safe_load(f)

#filter for info under current term
def get_current_term(terms, as_of="2025-01-03"):
    ref = datetime.fromisoformat(as_of)
    current = None
    
    for t in terms:
        start = datetime.fromisoformat(t["start"])
        end = datetime.fromisoformat(t["end"])
        if start <= ref <= end:
            current = t
    
    # if none explicitly cover the date, take the last term
    if current is None:
        current = terms[-1]
    
    return current

# %%
#create df with info per legislator (rows) and add specific columns
rows = []

for leg in legislators:
    term = get_current_term(leg["terms"])  # this is their current/active term

    rows.append({
        "id.bioguide": leg["id"]["bioguide"],
        "first": leg["name"]["first"],
        "last": leg["name"]["last"],
        "current_type": term["type"],       # "sen" or "rep"
        "current_party": term["party"],     # e.g. "Republican", "Democrat"
        "current_state": term["state"],
        "term_start": term["start"],
        "term_end": term["end"],
    })

df_legs = pd.DataFrame(rows)
df_legs.head()
# Out:
#   id.bioguide    first        last current_type current_party current_state  \
# 0     C000127    Maria    Cantwell          sen      Democrat            WA
# 1     K000367      Amy   Klobuchar          sen      Democrat            MN
# 2     S000033  Bernard     Sanders          sen   Independent            VT
# 3     W000802  Sheldon  Whitehouse          sen      Democrat            RI
# 4     B001261     John    Barrasso          sen    Republican            WY
#
#    term_start    term_end
# 0  2025-01-03  2031-01-03
# 1  2025-01-03  2031-01-03
# 2  2025-01-03  2031-01-03
# 3  2025-01-03  2031-01-03
# 4  2025-01-03  2031-01-03

# %%
len(df_legs)
# Out:
# 539

# %%
#merge dataframes

df_legs_media = df_rep_media.merge(df_legs, on="id.bioguide", how="left")
df_legs_media.head()
# Out:
#   id.bioguide id.thomas  id.govtrack   social.twitter    social.facebook  \
# 0     R000600     02222     412664.0         RepAmata         aumuaamata
# 1     Y000064     02019     412428.0     SenToddYoung   SenatorToddYoung
# 2     E000295     02283     412667.0     SenJoniErnst       senjoniernst
# 3     T000476     02291     412668.0    SenThomTillis  SenatorThomTillis
# 4     W000809     01991     412402.0  Rep_SteveWomack     RepSteveWomack
#
#           social.youtube_id  social.twitter_id     social.youtube  \
# 0  UCGdrLQbt1PYDTPsampx4t1A       3.026623e+09                NaN
# 1  UCuknj4PGn91gHDNAfboZEgQ       2.341285e+08       RepToddYoung
# 2  UCLwrmtF_84FIcK3TyMs4MIw       2.856788e+09                NaN
# 3  UCUD9VGV4SSGWjGdbn37Ea2w       2.964175e+09                NaN
# 4  UCXJbUDLYX-wGIhRuN66hqZw       2.344693e+08  CongressmanWomack
#
#   social.instagram  social.instagram_id social.mastodon        first  \
# 0              NaN                  NaN             NaN  Aumua Amata
# 1     sentoddyoung                  NaN             NaN         Todd
# 2     senjoniernst         1.582703e+09             NaN         Joni
# 3    senthomtillis                  NaN             NaN         Thom
# 4  rep_stevewomack                  NaN             NaN        Steve
#
#         last current_type current_party current_state  term_start    term_end
# 0  Radewagen          rep    Republican            AS  2025-01-03  2027-01-03
# 1      Young          sen    Republican            IN  2023-01-03  2029-01-03
# 2      Ernst          sen    Republican            IA  2021-01-03  2027-01-03
# 3     Tillis          sen    Republican            NC  2021-01-03  2027-01-03
# 4     Womack          rep    Republican            AR  2025-01-03  2027-01-03

# %%
#drop unecessary columns
#df_legs_media = df_legs_media.drop(columns=["id.thomas", "id.govtrack", "social.mastodon"])

#reorganize columns
df_legs_media = df_legs_media[["first", "last", "id.bioguide", "current_type", "current_party", "current_state", "term_start", "term_end", "social.youtube", "social.youtube_id",  "social.twitter", "social.twitter_id", "social.instagram","social.instagram_id", "social.facebook"]]

df_legs_media.tail()
# Out:
#      first     last id.bioguide current_type current_party current_state  \
# 522  Sarah  McBride     M001238          rep      Democrat            DE
# 523   Mark  Messmer     M001233          rep    Republican            IN
# 524   Josh    Riley     R000622          rep      Democrat            NY
# 525    Jim  Justice     J000312          sen    Republican            WV
# 526  Lance   Gooden     G000589          rep    Republican            TX
#
#      term_start    term_end            social.youtube social.youtube_id  \
# 522  2025-01-03  2027-01-03                       NaN               NaN
# 523  2025-01-03  2027-01-03                       NaN               NaN
# 524  2025-01-03  2027-01-03                       NaN               NaN
# 525  2025-01-14  2031-01-03                       NaN               NaN
# 526  2025-01-03  2027-01-03  UCaEs0pYlL_1cLlPBHfl0RIg               NaN
#
#     social.twitter  social.twitter_id           social.instagram  \
# 522            NaN                NaN  congresswomansarahmcbride
# 523            NaN                NaN           HouseRepublicans
# 524            NaN                NaN                 RepRileyNY
# 525            NaN                NaN              senjimjustice
# 526            NaN                NaN                        NaN
#
#      social.instagram_id            social.facebook
# 522                  NaN  CongresswomanSarahMcBride
# 523                  NaN         CongressmanMessmer
# 524                  NaN                 RepRileyNY
# 525                  NaN            100044187231175
# 526                  NaN                        NaN

# %%
#save merged df as csv
df_legs_media.to_csv("clean_data/df_legs_media.csv", index=False)

# %%
#load clean merged df 
clean_legs_media = pd.read_csv("clean_data/clean-df_legs_media.csv")

clean_legs_media.tail()
# Out:
#      first     last id.bioguide current_type current_party current_state  \
# 522  Sarah  McBride     M001238          rep      Democrat            DE
# 523   Mark  Messmer     M001233          rep    Republican            IN
# 524   Josh    Riley     R000622          rep      Democrat            NY
# 525    Jim  Justice     J000312          sen    Republican            WV
# 526  Lance   Gooden     G000589          rep    Republican            TX
#
#      term_start    term_end social.youtube         social.youtube_id  \
# 522  2025-01-03  2027-01-03            NaN                       NaN
# 523  2025-01-03  2027-01-03            NaN                       NaN
# 524  2025-01-03  2027-01-03            NaN                       NaN
# 525  2025-01-14  2031-01-03            NaN                       NaN
# 526  2025-01-03  2027-01-03            NaN  UCaEs0pYlL_1cLlPBHfl0RIg
#
#     social.twitter  social.twitter_id           social.instagram  \
# 522            NaN                NaN  congresswomansarahmcbride
# 523            NaN                NaN           HouseRepublicans
# 524            NaN                NaN                 RepRileyNY
# 525            NaN                NaN              senjimjustice
# 526            NaN                NaN                        NaN
#
#      social.instagram_id            social.facebook
# 522                  NaN  CongresswomanSarahMcBride
# 523                  NaN         CongressmanMessmer
# 524                  NaN                 RepRileyNY
# 525                  NaN            100044187231175
# 526                  NaN                        NaN

# %%
#new df filtering reps with youtube channels
df_reps_with_youtube = clean_legs_media[
    ((clean_legs_media["current_type"] == "rep") &  
     clean_legs_media["social.youtube_id"].notna()
    )
]

len(df_reps_with_youtube)
# Out:
# 242

# %%
df_reps_with_youtube.tail()
# Out:
#        first     last id.bioguide current_type current_party current_state  \
# 447  Harriet  Hageman     H001096          rep    Republican            WY
# 451  Celeste    Maloy     M001228          rep    Republican            UT
# 453  Timothy  Kennedy     K000402          rep      Democrat            NY
# 469     Jeff     Hurd     H001100          rep    Republican            CO
# 526    Lance   Gooden     G000589          rep    Republican            TX
#
#      term_start    term_end    social.youtube         social.youtube_id  \
# 447  2025-01-03  2027-01-03       @rephageman  UCYafjxwsbUrWxavqKPY4B-A
# 451  2025-01-03  2027-01-03  @RepCelesteMaloy  UCqHNoy1lbxNZhbMQUuxkb1Q
# 453  2025-01-03  2027-01-03    @reptimkennedy  UCDB-BzTPkdKjZvWLdRa0lUA
# 469  2025-01-03  2027-01-03               NaN  UCETJIbCBqsc2x9X1eT7g5bw
# 526  2025-01-03  2027-01-03               NaN  UCaEs0pYlL_1cLlPBHfl0RIg
#
#     social.twitter  social.twitter_id social.instagram  social.instagram_id  \
# 447     RepHageman                NaN              NaN                  NaN
# 451   RepMaloyUtah                NaN  RepCelesteMaloy                  NaN
# 453  reptimkennedy                NaN    reptimkennedy                  NaN
# 469    RepJeffHurd                NaN      repjeffhurd                  NaN
# 526            NaN                NaN              NaN                  NaN
#
#     social.facebook
# 447             NaN
# 451  61555755717517
# 453   reptimkennedy
# 469  61571570223582
# 526             NaN

# %%
#create column with youtube url using youtube ID indo
df_reps_with_youtube["youtube_url"] = df_reps_with_youtube["social.youtube_id"].apply(
    lambda x: f"https://www.youtube.com/channel/{x}" if pd.notna(x) else None
)

df_reps_with_youtube.head()
# Out:
# /var/folders/r2/wwj7bwds0239g96hdx5tn0900000gn/T/ipykernel_37074/993600350.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reps_with_youtube["youtube_url"] = df_reps_with_youtube["social.youtube_id"].apply(
#          first       last id.bioguide current_type current_party  \
# 0  Aumua Amata  Radewagen     R000600          rep    Republican
# 4        Steve     Womack     W000809          rep    Republican
# 5    Frederica     Wilson     W000808          rep      Democrat
# 6       Daniel    Webster     W000806          rep    Republican
# 8       Robert    Wittman     W000804          rep    Republican
#
#   current_state  term_start    term_end      social.youtube  \
# 0            AS  2025-01-03  2027-01-03                 NaN
# 4            AR  2025-01-03  2027-01-03   CongressmanWomack
# 5            FL  2025-01-03  2027-01-03  repfredericawilson
# 6            FL  2025-01-03  2027-01-03       repdanwebster
# 8            VA  2025-01-03  2027-01-03          RobWittman
#
#           social.youtube_id   social.twitter  social.twitter_id  \
# 0  UCGdrLQbt1PYDTPsampx4t1A         RepAmata       3.026623e+09
# 4  UCXJbUDLYX-wGIhRuN66hqZw  Rep_SteveWomack       2.344693e+08
# 5  UCP5QBhng_lHv-vJgE_h7lpA        RepWilson       2.340141e+08
# 6  UCCoX4VdU7U11eGEA0lbRtLw       RepWebster       2.815407e+08
# 8  UCIqIb-OaTbkIdU426eYIdPg       RobWittman       1.535641e+07
#
#   social.instagram  social.instagram_id social.facebook  \
# 0              NaN                  NaN      aumuaamata
# 4  rep_stevewomack                  NaN  RepSteveWomack
# 5        repwilson                  NaN       RepWilson
# 6              NaN                  NaN      RepWebster
# 8    reprobwittman                  NaN   RepRobWittman
#
#                                          youtube_url
# 0  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 4  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 5  https://www.youtube.com/channel/UCP5QBhng_lHv-...
# 6  https://www.youtube.com/channel/UCCoX4VdU7U11e...
# 8  https://www.youtube.com/channel/UCIqIb-OaTbkId...

# %%
#save df as csv 
df_reps_with_youtube.to_csv("clean_data/df_reps_with_youtube.csv", index=False)

# %%
#data frame with democrats only
dems_youtube = df_reps_with_youtube[df_reps_with_youtube["current_party"] == "Democrat"]

dems_youtube.head()
# Out:
#         first               last id.bioguide current_type current_party  \
# 5   Frederica             Wilson     W000808          rep      Democrat
# 12     Debbie  Wasserman Schultz     W000797          rep      Democrat
# 16     Maxine             Waters     W000187          rep      Democrat
# 18      Nydia          Velázquez     V000081          rep      Democrat
# 19       Paul              Tonko     T000469          rep      Democrat
#
#    current_state  term_start    term_end       social.youtube  \
# 5             FL  2025-01-03  2027-01-03   repfredericawilson
# 12            FL  2025-01-03  2027-01-03  RepWassermanSchultz
# 16            CA  2025-01-03  2027-01-03         MaxineWaters
# 18            NY  2025-01-03  2027-01-03       nydiavelazquez
# 19            NY  2025-01-03  2027-01-03         reppaultonko
#
#            social.youtube_id   social.twitter  social.twitter_id  \
# 5   UCP5QBhng_lHv-vJgE_h7lpA        RepWilson       2.340141e+08
# 12  UCfHQiJVvMlYbVAxrMSLdO4w     RepDWStweets       1.140648e+09
# 16  UCOQ2js1VYFlo74n7Ns8WsLQ  RepMaxineWaters       3.668604e+07
# 18  UCqMKPkKeeHFOOiZ9vxhXGVg   NydiaVelazquez       1.643693e+08
# 19  UC3P2SGFmmuCYRsjeso0hOQQ     RepPaulTonko       8.411935e+07
#
#    social.instagram  social.instagram_id social.facebook  \
# 5         repwilson                  NaN       RepWilson
# 12     RepDWSTweets                  NaN          RepDWS
# 16  repmaxinewaters                  NaN    MaxineWaters
# 18              NaN                  NaN      8037068318
# 19     reppaultonko                  NaN    reppaultonko
#
#                                           youtube_url
# 5   https://www.youtube.com/channel/UCP5QBhng_lHv-...
# 12  https://www.youtube.com/channel/UCfHQiJVvMlYbV...
# 16  https://www.youtube.com/channel/UCOQ2js1VYFlo7...
# 18  https://www.youtube.com/channel/UCqMKPkKeeHFOO...
# 19  https://www.youtube.com/channel/UC3P2SGFmmuCYR...

# %%
len(dems_youtube)
# Out:
# 120

# %%
#data frame with republicans only
gop_youtube = df_reps_with_youtube[df_reps_with_youtube["current_party"] == "Republican"]

gop_youtube.head()
# Out:
#           first       last id.bioguide current_type current_party  \
# 0   Aumua Amata  Radewagen     R000600          rep    Republican
# 4         Steve     Womack     W000809          rep    Republican
# 6        Daniel    Webster     W000806          rep    Republican
# 8        Robert    Wittman     W000804          rep    Republican
# 11          Tim    Walberg     W000798          rep    Republican
#
#    current_state  term_start    term_end     social.youtube  \
# 0             AS  2025-01-03  2027-01-03                NaN
# 4             AR  2025-01-03  2027-01-03  CongressmanWomack
# 6             FL  2025-01-03  2027-01-03      repdanwebster
# 8             VA  2025-01-03  2027-01-03         RobWittman
# 11            MI  2025-01-03  2027-01-03         RepWalberg
#
#            social.youtube_id   social.twitter  social.twitter_id  \
# 0   UCGdrLQbt1PYDTPsampx4t1A         RepAmata       3.026623e+09
# 4   UCXJbUDLYX-wGIhRuN66hqZw  Rep_SteveWomack       2.344693e+08
# 6   UCCoX4VdU7U11eGEA0lbRtLw       RepWebster       2.815407e+08
# 8   UCIqIb-OaTbkIdU426eYIdPg       RobWittman       1.535641e+07
# 11  UChpf3_3Wn8f3qSJbsYXrhvg       RepWalberg       2.378630e+08
#
#    social.instagram  social.instagram_id social.facebook  \
# 0               NaN                  NaN      aumuaamata
# 4   rep_stevewomack                  NaN  RepSteveWomack
# 6               NaN                  NaN      RepWebster
# 8     reprobwittman                  NaN   RepRobWittman
# 11       repwalberg                  NaN      RepWalberg
#
#                                           youtube_url
# 0   https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 4   https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 6   https://www.youtube.com/channel/UCCoX4VdU7U11e...
# 8   https://www.youtube.com/channel/UCIqIb-OaTbkId...
# 11  https://www.youtube.com/channel/UChpf3_3Wn8f3q...

# %%
len(gop_youtube)
# Out:
# 122

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"


# -------------------- exceptions --------------------

class RequestLimitReached(Exception):
    """Stop cleanly when we hit either request cap or keys cap."""
    pass


# -------------------- API key manager --------------------

class ApiKeyManager:
    """
    Manages multiple API keys and a YouTube client.
    Automatically rotates keys on quotaExceeded.
    Tracks exhausted keys *globally* so they are skipped
    even when scraping the next channel.
    """

    # Class-level set of API keys already exhausted in this Python session
    _exhausted_keys = set()

    def __init__(self, api_keys):
        if not api_keys:
            raise ValueError("You must provide at least one API key")

        self.api_keys = api_keys

        # Find first non-exhausted key
        idx = self._find_next_key_index(start=0)
        if idx is None:
            raise RequestLimitReached("All API keys exhausted (quota).")

        self.current_index = idx
        self.youtube = self._build_service()

    @property
    def current_key(self):
        return self.api_keys[self.current_index]

    def _build_service(self):
        return build(
            YOUTUBE_API_SERVICE_NAME,
            YOUTUBE_API_VERSION,
            developerKey=self.current_key
        )

    @classmethod
    def mark_exhausted(cls, key):
        """Mark an API key as globally exhausted."""
        cls._exhausted_keys.add(key)

    def _find_next_key_index(self, start):
        """Return index of next available (non-exhausted) key, else None."""
        for i in range(start, len(self.api_keys)):
            if self.api_keys[i] not in ApiKeyManager._exhausted_keys:
                return i
        return None

    def rotate_key(self):
        """
        Mark current key as exhausted, then switch to the next
        available key. Raise RequestLimitReached if none are left.
        """
        ApiKeyManager.mark_exhausted(self.current_key)

        next_idx = self._find_next_key_index(start=self.current_index + 1)
        if next_idx is None:
            raise RequestLimitReached("All API keys exhausted (quota).")

        print(
            f"⚠️ Key exhausted. Switching to key #{next_idx + 1}/{len(self.api_keys)}."
        )

        self.current_index = next_idx
        self.youtube = self._build_service()

    def execute_request(self, build_request_fn):
        """
        build_request_fn: function(youtube_client) -> API request
        Handles:
          - global request_counter
          - quota errors -> mark key exhausted, rotate, retry
        """
        while True:
            
            request = build_request_fn(self.youtube)

            try:
                return request.execute()

            except HttpError as e:
                reason = ""
                try:
                    reason = e.error_details[0].get("reason", "")
                except Exception:
                    pass

                # Quota-based errors → rotate keys
                if reason in {
                    "quotaExceeded",
                    "dailyLimitExceeded",
                    "rateLimitExceeded",
                    "userRateLimitExceeded",
                    "usageLimits",
                } or (e.resp.status == 403 and "quota" in str(e).lower()):
                    self.rotate_key()
                    continue  # retry with new key

                # Any other error should bubble up
                raise


#--
# -------------------- helper functions --------------------

def get_uploads_playlist_id(channel_id, key_manager, request_counter=None):
    """
    Uses the channels.list endpoint to get the uploads playlist id
    for a channel.
    """

    def build_request(yt):
        return yt.channels().list(
            part="contentDetails",
            id=channel_id
        )

    response = key_manager.execute_request(build_request)
    items = response.get("items", [])
    if not items:
        return None
    return items[0]["contentDetails"]["relatedPlaylists"]["uploads"]


def get_all_video_ids_from_playlist(
    playlist_id,
    key_manager,
    max_videos=None,
    request_counter=None
):
    """
    Fetch all video IDs from a playlist, handling playlistNotFound and
    rotating API keys on quota errors.
    """
    video_ids = []
    next_page_token = None

    while True:
        def build_request(yt):
            return yt.playlistItems().list(
                part="contentDetails",
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )

        try:
            response = key_manager.execute_request(build_request)
        except HttpError as e:
            reason = ""
            try:
                reason = e.error_details[0].get("reason", "")
            except Exception:
                pass

            if reason == "playlistNotFound":
                print(f"⚠️ Playlist not found or inaccessible: {playlist_id}. Skipping.")
                return []  # no videos for this channel
            else:
                raise e

        for item in response.get("items", []):
            video_ids.append(item["contentDetails"]["videoId"])
            if max_videos and len(video_ids) >= max_videos:
                return video_ids

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return video_ids


def get_video_comments(
    video_id,
    key_manager,
    max_comments=None,
    request_counter=None
):
    """
    Get comments (and replies) for a single video, rotating keys on quota errors
    and stopping cleanly on request limit.
    """
    comments = []
    next_page_token = None

    while True:
        def build_request(yt):
            return yt.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
                textFormat="plainText"
            )

        # account for errors and request limit
        try:
            response = key_manager.execute_request(build_request)
        except RequestLimitReached:
            # return whatever we have so far for this video
            return comments
        except HttpError as e:
            error_reason = ""
            try:
                error_reason = e.error_details[0].get("reason", "")
            except Exception:
                pass

            if error_reason == "commentsDisabled":
                return []   # return empty for this video
            else:
                raise e

        for item in response.get("items", []):
            top_comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "channel_id": item["snippet"]["channelId"],
                "video_id": video_id,
                "comment_id": item["snippet"]["topLevelComment"]["id"],
                "author": top_comment.get("authorDisplayName"),
                "text": top_comment.get("textDisplay"),
                "published_at": top_comment.get("publishedAt"),
                "is_reply": False,
                "parent_id": None
            })

            # capture replies
            for reply in item.get("replies", {}).get("comments", []):
                reply_snip = reply["snippet"]
                comments.append({
                    "channel_id": item["snippet"]["channelId"],
                    "video_id": video_id,
                    "comment_id": reply["id"],
                    "author": reply_snip.get("authorDisplayName"),
                    "text": reply_snip.get("textDisplay"),
                    "published_at": reply_snip.get("publishedAt"),
                    "like_count": reply_snip.get("likeCount"),
                    "is_reply": True,
                    "parent_id": item["snippet"]["topLevelComment"]["id"]
                })

            if max_comments and len(comments) >= max_comments:
                return comments

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return comments


# -------------------- top-level scrape function --------------------

def scrape_comments(
    channel_id,
    api_keys,
    max_comments=None,
    max_requests=None
):
    """
    Scrape comments from a channel, using a *list* of API keys.
    Rotates to the next key when one hits its quota.

    api_keys: list of strings, e.g. ["KEY1", "KEY2", ...]
    max_requests: global max number of requests across keys (optional)
    """

    key_manager = ApiKeyManager(api_keys)

    # shared counter object passed to all helper functions
    request_counter = None
    if max_requests is not None:
        request_counter = {"max": max_requests, "count": 0}

    all_comments = []

    try:
        playlist_id = get_uploads_playlist_id(
            channel_id,
            key_manager,
            request_counter=request_counter
        )
        if not playlist_id:
            return []

        video_ids = get_all_video_ids_from_playlist(
            playlist_id,
            key_manager,
            request_counter=request_counter
        )

        for vid in video_ids:
            video_comments = get_video_comments(
                vid,
                key_manager,
                max_comments=max_comments,
                request_counter=request_counter
            )

            # filter by date if you want (note: your comparison assumes ISO strings)
            filtered_comments = [
                c for c in video_comments
                if '2021' <= c['published_at'] <= '2025-01'
            ]

            all_comments.extend(filtered_comments)

    except RequestLimitReached as e:
        # hit either the global max_requests or ran out of keys
        print(f"Stopping scrape for this channel: {e}")

    return all_comments

# %%
df_reps_with_youtube.loc[
    (df_reps_with_youtube["first"] == "Steve") &
    (df_reps_with_youtube["last"] == "Womack"),
    "social.youtube_id"
]
# Out:
# 4    UCXJbUDLYX-wGIhRuN66hqZw
# Name: social.youtube_id, dtype: object

# %%
womack_comments = scrape_comments("UCXJbUDLYX-wGIhRuN66hqZw")

# %%
len(womack_comments)
# Out:
# 66

# %%
print(womack_comments[:5])
# Out:
# [{'channel_id': 'UCXJbUDLYX-wGIhRuN66hqZw', 'video_id': 'BI4_jtPh67M', 'comment_id': 'Ugwr0YkkCsMK9Z7ULHt4AaABAg', 'author': '@eddoura', 'text': 'Mr.Kermit Womack was a GIANT towering figure. I started listening to his show in 2009. I never missed a show. Thanks for the great memories, Colonel Womack 👏🏻👍🇺🇸', 'published_at': '2024-10-11T23:14:24Z', 'is_reply': False, 'parent_id': None}, {'channel_id': 'UCXJbUDLYX-wGIhRuN66hqZw', 'video_id': 'BI4_jtPh67M', 'comment_id': 'UgxLfWhhiGd1VpF_V9N4AaABAg', 'author': '@Bluefrog247', 'text': 'I will greatly miss listening to your father every day.', 'published_at': '2024-07-03T01:58:59Z', 'is_reply': False, 'parent_id': None}, {'channel_id': 'UCXJbUDLYX-wGIhRuN66hqZw', 'video_id': 'BI4_jtPh67M', 'comment_id': 'UgzToKNUidyAtuhTJKJ4AaABAg', 'author': '@djaztec9075', 'text': "Today was a sad day in broadcasting. I'm grateful for The Colonel and the unique service he provided to his listening audience and the community. \nWe Love Ya!", 'published_at': '2024-07-01T22:51:10Z', 'is_reply': False, 'parent_id': None}, {'channel_id': 'UCXJbUDLYX-wGIhRuN66hqZw', 'video_id': 'BI4_jtPh67M', 'comment_id': 'UgzghG_GmM8M2rfQFRt4AaABAg', 'author': '@tomoneal3835', 'text': 'Thank you, Congressman. Your dad will be missed 😢', 'published_at': '2024-06-26T02:43:02Z', 'is_reply': False, 'parent_id': None}, {'channel_id': 'UCXJbUDLYX-wGIhRuN66hqZw', 'video_id': 'BI4_jtPh67M', 'comment_id': 'UgzghG_GmM8M2rfQFRt4AaABAg.A57uhn9Q20wA5JqFpKe5Uz', 'author': '@tomoneal3835', 'text': "The Colonel will be missed.  I always enjoyed listening to him about his childhood and growing up. It reminded me of listening to my grandpa's stories.  God bless Kermit Womack 🙏", 'published_at': '2024-06-30T17:55:00Z', 'like_count': 1, 'is_reply': True, 'parent_id': 'UgzghG_GmM8M2rfQFRt4AaABAg'}]

# %%
API_KEYS = [
    "AIzaSyDV3LYjKX8gI5mn-TjIXyenyui64iDc1vw","AIzaSyAXkVT6PiaSvn15LL7inYh7P09dnkjWUIQ", "AIzaSyCiqcMqefT-qILLw-9t3OxWdZr6O_HKsaY",
    "AIzaSyCglGtrTS6Aqt55LA4fWQuxK2603SbFP3c", "AIzaSyB1GOlDV07Usvk67B5IbjjB2m6lKDbRs5Y","AIzaSyCehXxnJbMZEckKYBfFUdg1fuVnHypuawY",
    "AIzaSyDZqlW6kcxwOVW4u9wS1X3X6h-tEmRIHVQ", "AIzaSyDA9vAcT5scVuOTQgxT6lkHR2wgbe1oFtE", "AIzaSyCArSxae_CAYvDT1Ldg4ijnDXJ0RwDpxcI",
    "AIzaSyBgJm8tSOI-ny9iZ2wMRvQKGCQ5msI3rVo", "AIzaSyCs2HF1WeLY5oO6hlSbbFP-9VYukCzbMyY", "AIzaSyBt703XB4cW1dFMAvdVwwVem9DA9Pp1wQQ",
    "AIzaSyCYOtg1oi9NGx9izzQqMzYKRzCakJ4VPK8", "AIzaSyDFqDRKeXmLva5oAusnxGuPx7iWZOGCLJs", "AIzaSyBDlfe1NYP_a50fqAhrrLfHlgr-S3tEL3I"
    
]

import os
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

output_file = "reps_youtube_comments_2021_2025.csv"

# 1. Look at existing CSV and figure out which channel_ids are already done
if os.path.exists(output_file):
    try:
        existing_df = pd.read_csv(output_file, usecols=["channel_id"])
        processed_channels = set(existing_df["channel_id"].dropna().unique())
        first_write = False
        print(f"Resuming: found {len(processed_channels)} channels already in {output_file}")
    except Exception as e:
        # If something is weird with the existing file, start fresh
        print(f"⚠️ Could not read existing {output_file} cleanly ({e}). Starting from scratch.")
        os.remove(output_file)
        processed_channels = set()
        first_write = True
else:
    processed_channels = set()
    first_write = True

# Full list of channel IDs we want to process, skipping those already in the CSV
all_channel_ids = (
    df_reps_with_youtube["social.youtube_id"]
    .dropna()
    .astype(str)
    .unique()
)
channel_ids_to_process = [
    cid for cid in all_channel_ids if cid not in processed_channels
]

print(f"Total channels in df: {len(all_channel_ids)}")
print(f"Channels to process now: {len(channel_ids_to_process)}")

def process_channel(channel_id):
    """
    Worker function for one channel:
    - calls scrape_comments
    - returns a DataFrame (or None) for that channel
    """
    print(f"▶️ Starting channel {channel_id}")
    comments = scrape_comments(channel_id, api_keys=API_KEYS)

    if not comments:
        print(f"⏭ No comments for channel {channel_id}")
        return None

    df_tmp = pd.DataFrame(comments)
    # Ensure channel_id column exists (it should from scrape_comments)
    if "channel_id" not in df_tmp.columns:
        df_tmp["channel_id"] = channel_id

    print(f"✅ Finished channel {channel_id} with {len(df_tmp)} comments")
    return df_tmp

# 2. Multithreading: process several channels in parallel
max_workers = 4  # adjust based on how aggressive you want to be

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = {
        executor.submit(process_channel, cid): cid
        for cid in channel_ids_to_process
    }

    for future in as_completed(futures):
        cid = futures[future]
        try:
            df_tmp = future.result()
        except Exception as e:
            print(f"❌ Error processing channel {cid}: {e}")
            continue

        if df_tmp is None or df_tmp.empty:
            continue

        # Append to CSV, writing header only the first time
        df_tmp.to_csv(
            output_file,
            mode="a",
            index=False,
            header=first_write
        )
        first_write = False
# Out:
# Resuming: found 34 channels already in reps_youtube_comments_2021_2025.csv
# Total channels in df: 242
# Channels to process now: 208
# ▶️ Starting channel UChpf3_3Wn8f3qSJbsYXrhvg
# ▶️ Starting channel UChVFKLZkRoHQDhp4zNvEezQ
# ▶️ Starting channel UCZVtTydu0-MSK6G12GaKA4g
# ▶️ Starting channel UCMh04KC4LfIzKoXh2Xws_pw
# ⚠️ Key exhausted. Switching to key #2/15.
# ⚠️ Key exhausted. Switching to key #2/15.
# ⚠️ Key exhausted. Switching to key #2/15.
# ⚠️ Key exhausted. Switching to key #2/15.
# ⚠️ Key exhausted. Switching to key #3/15.
# ⚠️ Key exhausted. Switching to key #3/15.
# ⚠️ Key exhausted. Switching to key #3/15.
# ⚠️ Key exhausted. Switching to key #3/15.
# ⏭ No comments for channel UCZVtTydu0-MSK6G12GaKA4g
# ▶️ Starting channel UCSqqxVkvskHq3cY2MCbTZsw
# ⚠️ Key exhausted. Switching to key #4/15.
# ⚠️ Key exhausted. Switching to key #4/15.
# ⚠️ Key exhausted. Switching to key #4/15.
# ⚠️ Key exhausted. Switching to key #4/15.
# ⏭ No comments for channel UChVFKLZkRoHQDhp4zNvEezQ
# ▶️ Starting channel UCCs9o1XaSsCsqNpO0iO0_Ew
# ✅ Finished channel UCSqqxVkvskHq3cY2MCbTZsw with 17 comments
# ▶️ Starting channel UCRw6sGE0PH7_FCeTT3PQRaA
# ⏭ No comments for channel UChpf3_3Wn8f3qSJbsYXrhvg
# ▶️ Starting channel UC3sZJSdiZo2EBHbsOlsnI7A
# ✅ Finished channel UC3sZJSdiZo2EBHbsOlsnI7A with 50 comments
# ▶️ Starting channel UCljJnwgQS6Z6-NypDyqKJZQ
# ⏭ No comments for channel UCljJnwgQS6Z6-NypDyqKJZQ
# ▶️ Starting channel UCpiUqp2ZF64tXqgR_EQo27g
# ✅ Finished channel UCCs9o1XaSsCsqNpO0iO0_Ew with 68 comments
# ▶️ Starting channel UCVSBVHoWu-eWnBBQaMKZ_sQ
# ✅ Finished channel UCMh04KC4LfIzKoXh2Xws_pw with 36 comments
# ▶️ Starting channel UCxL4zG0YWqC5XTO4af_FOgw
# ✅ Finished channel UCVSBVHoWu-eWnBBQaMKZ_sQ with 60 comments
# ▶️ Starting channel UCMv7LsJtiyO4AJcbRux5CxQ
# ✅ Finished channel UCxL4zG0YWqC5XTO4af_FOgw with 2 comments
# ▶️ Starting channel UCGPsvFF-9WfpdRSCcCrPLiQ
# ✅ Finished channel UCRw6sGE0PH7_FCeTT3PQRaA with 744 comments
# ▶️ Starting channel UCdYZbKY8pkWAThqwC3fdVMg
# ✅ Finished channel UCpiUqp2ZF64tXqgR_EQo27g with 183 comments
# ▶️ Starting channel UCOaQ79adORFcaTuJZoIFuZQ
# ✅ Finished channel UCGPsvFF-9WfpdRSCcCrPLiQ with 9 comments
# ▶️ Starting channel UCoz6u3ooQxoijsWvhoQ0D-A
# ⏭ No comments for channel UCMv7LsJtiyO4AJcbRux5CxQ
# ▶️ Starting channel UC7KPV4xdxO2dms9vl6tETmg
# ✅ Finished channel UCdYZbKY8pkWAThqwC3fdVMg with 4 comments
# ▶️ Starting channel UCIJUNf22o09nO02oQPLKQ6w
# ✅ Finished channel UC7KPV4xdxO2dms9vl6tETmg with 8 comments
# ▶️ Starting channel UCPFBhS00ivPV585GlnNlyqA
# ✅ Finished channel UCOaQ79adORFcaTuJZoIFuZQ with 243 comments
# ▶️ Starting channel UCqMici9I7nz_i-PN7eSYjwQ
# ✅ Finished channel UCIJUNf22o09nO02oQPLKQ6w with 200 comments
# ▶️ Starting channel UCQPlLLiMnysMmeJ5qUSSjQg
# ✅ Finished channel UCoz6u3ooQxoijsWvhoQ0D-A with 143 comments
# ▶️ Starting channel UCCeB6czh6nhCHxOMCk_V4yA
# ✅ Finished channel UCQPlLLiMnysMmeJ5qUSSjQg with 650 comments
# ▶️ Starting channel UCvxgqX65cdhHNjJn64cgY9g
# ✅ Finished channel UCCeB6czh6nhCHxOMCk_V4yA with 4 comments
# ▶️ Starting channel UCzxqD7EY_Rdvbc0spbaYkJA
# ⚠️ Key exhausted. Switching to key #5/15.
# ⚠️ Key exhausted. Switching to key #5/15.
# ⚠️ Key exhausted. Switching to key #5/15.
# ⚠️ Key exhausted. Switching to key #5/15.
# ✅ Finished channel UCqMici9I7nz_i-PN7eSYjwQ with 1397 comments
# ▶️ Starting channel UC5orqw_9acsKWSRbrqTDXBw
# ✅ Finished channel UCzxqD7EY_Rdvbc0spbaYkJA with 373 comments
# ▶️ Starting channel UCRym1qsO72C39gX6pBu4icg
# ✅ Finished channel UC5orqw_9acsKWSRbrqTDXBw with 283 comments
# ▶️ Starting channel UCFtgMZm1YUXaZ8OtOj-GDjA
# ✅ Finished channel UCvxgqX65cdhHNjJn64cgY9g with 27 comments
# ▶️ Starting channel UCTtRrJkM-R-f2K0byCMvHgw
# ✅ Finished channel UCTtRrJkM-R-f2K0byCMvHgw with 385 comments
# ▶️ Starting channel UCggineJcxJn80TRXxdQbx6w
# ✅ Finished channel UCggineJcxJn80TRXxdQbx6w with 20 comments
# ▶️ Starting channel UCvjuSLoi3hS0ECQvJLhwOkA
# ✅ Finished channel UCRym1qsO72C39gX6pBu4icg with 72 comments
# ▶️ Starting channel UCpEEd0Plxx5D78pI4a4mFTQ
# ✅ Finished channel UCvjuSLoi3hS0ECQvJLhwOkA with 379 comments
# ▶️ Starting channel UCN-kiLKyHPcfRVZ28sAHS_g
# ✅ Finished channel UCpEEd0Plxx5D78pI4a4mFTQ with 8 comments
# ▶️ Starting channel UC9ROfGBm7kSLCEDYwFF6McQ
# ✅ Finished channel UC9ROfGBm7kSLCEDYwFF6McQ with 588 comments
# ▶️ Starting channel UCWFQCRTHwsHg9P1Hf-EQtew
# ✅ Finished channel UCWFQCRTHwsHg9P1Hf-EQtew with 59 comments
# ▶️ Starting channel UCLKAkVl4BHRK73lmDiIgPYg
# ✅ Finished channel UCFtgMZm1YUXaZ8OtOj-GDjA with 1386 comments
# ▶️ Starting channel UCfcbYOvdEXZNelM8T05nK-w
# ✅ Finished channel UCfcbYOvdEXZNelM8T05nK-w with 30 comments
# ▶️ Starting channel UCprUnnEgM2VUGmAKSaZXCSw
# ✅ Finished channel UCLKAkVl4BHRK73lmDiIgPYg with 30 comments
# ▶️ Starting channel UCGVIfe1T2hO1Lx7ap5Wkv1w
# ⏭ No comments for channel UCprUnnEgM2VUGmAKSaZXCSw
# ▶️ Starting channel UC_NJlnsOBjOameUwZk0rvsA
# ✅ Finished channel UCN-kiLKyHPcfRVZ28sAHS_g with 378 comments
# ▶️ Starting channel UC8SuQiuL2P9fUHAxuRoTdUQ
# ✅ Finished channel UC8SuQiuL2P9fUHAxuRoTdUQ with 1 comments
# ▶️ Starting channel UCVgEOdJx3tyILO9EjZ-heEQ
# ⚠️ Key exhausted. Switching to key #6/15.
# ⚠️ Key exhausted. Switching to key #6/15.
# ⚠️ Key exhausted. Switching to key #6/15.
# ⚠️ Key exhausted. Switching to key #6/15.
# ✅ Finished channel UCVgEOdJx3tyILO9EjZ-heEQ with 3 comments
# ▶️ Starting channel UCVC-7CLFjXczoihr5FxDLsw
# ✅ Finished channel UCVC-7CLFjXczoihr5FxDLsw with 9 comments
# ▶️ Starting channel UCVgXX23eJEai6GiBOKO6dvA
# ✅ Finished channel UCGVIfe1T2hO1Lx7ap5Wkv1w with 138 comments
# ▶️ Starting channel UCvqzPm_YnNkfEHpm3SEMJMQ
# ✅ Finished channel UCPFBhS00ivPV585GlnNlyqA with 85543 comments
# ▶️ Starting channel UC9pkaOrhPfouzkJ8oAdI-1w
# ✅ Finished channel UC9pkaOrhPfouzkJ8oAdI-1w with 28 comments
# ▶️ Starting channel UCIyU_UA_JEa14gvAwhquKqg
# ✅ Finished channel UC_NJlnsOBjOameUwZk0rvsA with 9 comments
# ▶️ Starting channel UC5MEj7YOX_QdKoqD_HRxP3A
# ✅ Finished channel UCVgXX23eJEai6GiBOKO6dvA with 121 comments
# ▶️ Starting channel UCY4DEy41NxOTdcF8_XAVZvw
# ✅ Finished channel UC5MEj7YOX_QdKoqD_HRxP3A with 45 comments
# ▶️ Starting channel UC2z1uu1n4-60xXs5x1mvLJw
# ⏭ No comments for channel UCvqzPm_YnNkfEHpm3SEMJMQ
# ▶️ Starting channel UCxF9veLBrkr_CqVq5eFYVGg
# ✅ Finished channel UCxF9veLBrkr_CqVq5eFYVGg with 17 comments
# ▶️ Starting channel UC71CAgpg1gbLTew_pfTneGA
# ✅ Finished channel UCIyU_UA_JEa14gvAwhquKqg with 440 comments
# ▶️ Starting channel UCd00b7TpKDZIr-Ujhaktvjg
# ✅ Finished channel UCY4DEy41NxOTdcF8_XAVZvw with 11 comments
# ▶️ Starting channel UC0IkAeEiwgzSRTD1TDSvuBw
# ✅ Finished channel UCd00b7TpKDZIr-Ujhaktvjg with 29 comments
# ▶️ Starting channel UCjOGx2iqSn1r3BQxaVgYhYw
# ✅ Finished channel UC71CAgpg1gbLTew_pfTneGA with 372 comments
# ▶️ Starting channel UCKvwsFNGD4sDkE_9g-2ft0w
# ✅ Finished channel UCjOGx2iqSn1r3BQxaVgYhYw with 9 comments
# ▶️ Starting channel UCHg516zJKbIBtXFAJ0nu3XQ
# ✅ Finished channel UCHg516zJKbIBtXFAJ0nu3XQ with 63 comments
# ▶️ Starting channel UCJg4F1irmSFeKoXZBaZbX2w
# ✅ Finished channel UC2z1uu1n4-60xXs5x1mvLJw with 40 comments
# ▶️ Starting channel UCYVmbsjoNbQ4j-PCQIYgpWQ
# ✅ Finished channel UC0IkAeEiwgzSRTD1TDSvuBw with 524 comments
# ▶️ Starting channel UCTu9xz2VYk-jtQv0TVsLyYA
# ✅ Finished channel UCJg4F1irmSFeKoXZBaZbX2w with 102 comments
# ▶️ Starting channel UCJSZRrAcd5i1bHLjR66PZdg
# ✅ Finished channel UCTu9xz2VYk-jtQv0TVsLyYA with 73 comments
# ▶️ Starting channel UClJCTCo53Zk6b4kUL-bbdzg
# ⚠️ Key exhausted. Switching to key #7/15.
# ⚠️ Key exhausted. Switching to key #7/15.
# ⚠️ Key exhausted. Switching to key #7/15.
# ⚠️ Key exhausted. Switching to key #7/15.
# ✅ Finished channel UClJCTCo53Zk6b4kUL-bbdzg with 68 comments
# ▶️ Starting channel UCicixINQr_-3cFHI2bJzFpQ
# ✅ Finished channel UCJSZRrAcd5i1bHLjR66PZdg with 115 comments
# ▶️ Starting channel UCEk5viAhxaW_2OK20-yBwzQ
# ✅ Finished channel UCKvwsFNGD4sDkE_9g-2ft0w with 957 comments
# ▶️ Starting channel UC9Q1qCvnQR7rHERjTjJl5Pg
# ✅ Finished channel UCicixINQr_-3cFHI2bJzFpQ with 21 comments
# ▶️ Starting channel UC2CRp1KF5uljZyhDRPR-72Q
# ⏭ No comments for channel UC2CRp1KF5uljZyhDRPR-72Q
# ▶️ Starting channel UCzgrU5PT_HHRgf5hXPen4dQ
# ✅ Finished channel UC9Q1qCvnQR7rHERjTjJl5Pg with 1 comments
# ▶️ Starting channel UCSDk-cyNPCo1iy6rweSPmBw
# ✅ Finished channel UCEk5viAhxaW_2OK20-yBwzQ with 4 comments
# ▶️ Starting channel UCy2v2DXXvQnbRc8Zx77Dnsg
# ✅ Finished channel UCYVmbsjoNbQ4j-PCQIYgpWQ with 456 comments
# ▶️ Starting channel UCVL2s6x7f7H0ZJ-uwU0pQ6Q
# ⏭ No comments for channel UCy2v2DXXvQnbRc8Zx77Dnsg
# ▶️ Starting channel UCdhrT09_XMr31tuI8OcKsjQ
# ⚠️ Playlist not found or inaccessible: UUdhrT09_XMr31tuI8OcKsjQ. Skipping.
# ⏭ No comments for channel UCdhrT09_XMr31tuI8OcKsjQ
# ▶️ Starting channel UCdg2ybvoHsSW6t7iJnKHlNg
# ✅ Finished channel UCdg2ybvoHsSW6t7iJnKHlNg with 29 comments
# ▶️ Starting channel UCBtfmMMQarjtLB9U_pWMOhw
# ✅ Finished channel UCzgrU5PT_HHRgf5hXPen4dQ with 4 comments
# ▶️ Starting channel UCJU6SP1ppp1ZhSiqZLiFgDA
# ✅ Finished channel UCSDk-cyNPCo1iy6rweSPmBw with 29 comments
# ▶️ Starting channel UCvUuV7FiJfJi1yux4qozgMg
# ✅ Finished channel UCJU6SP1ppp1ZhSiqZLiFgDA with 105 comments
# ▶️ Starting channel UCQK77QJxW7Xr-S3zqeMd-0g
# ✅ Finished channel UCvUuV7FiJfJi1yux4qozgMg with 121 comments
# ▶️ Starting channel UCsRxWnFdRiV2od1O5v5nEeQ
# ✅ Finished channel UCsRxWnFdRiV2od1O5v5nEeQ with 9 comments
# ▶️ Starting channel UCdJhDw-YbdH0RHfWK0sIfiw
# ✅ Finished channel UCBtfmMMQarjtLB9U_pWMOhw with 207 comments
# ▶️ Starting channel UCUzz1XDn862fxirervSB2Yw
# ✅ Finished channel UCdJhDw-YbdH0RHfWK0sIfiw with 19 comments
# ▶️ Starting channel UC_irxhmLqVenTFPxDxznG6g
# ✅ Finished channel UCVL2s6x7f7H0ZJ-uwU0pQ6Q with 245 comments
# ▶️ Starting channel UCz5b47WER_u3dUGV_Zi70dQ
# ✅ Finished channel UCUzz1XDn862fxirervSB2Yw with 273 comments
# ▶️ Starting channel UCpMthf8y7bEMJH_td0dznRQ
# ✅ Finished channel UCQK77QJxW7Xr-S3zqeMd-0g with 67 comments
# ▶️ Starting channel UCFrC4Ouk5R6xQztS9PZin_A
# ✅ Finished channel UCpMthf8y7bEMJH_td0dznRQ with 6 comments
# ▶️ Starting channel UCpmXOtvvXC3GE8o9VxYNK7g
# ✅ Finished channel UCFrC4Ouk5R6xQztS9PZin_A with 59 comments
# ▶️ Starting channel UCLhcNPX2nNQLNzwKW0nEykg
# ✅ Finished channel UC_irxhmLqVenTFPxDxznG6g with 92 comments
# ▶️ Starting channel UCtVl3kb7Xvt3pY7l6x-M6LA
# ✅ Finished channel UCLhcNPX2nNQLNzwKW0nEykg with 2 comments
# ▶️ Starting channel UCzj9-27Lr4gcqopmZAobXXg
# ✅ Finished channel UCz5b47WER_u3dUGV_Zi70dQ with 736 comments
# ▶️ Starting channel UCtCNUDo3-I1gsd_03ppDfZg
# ✅ Finished channel UCtCNUDo3-I1gsd_03ppDfZg with 888 comments
# ▶️ Starting channel UCgaI52w7QKI8LtkSeCCmSuw
# ✅ Finished channel UCtVl3kb7Xvt3pY7l6x-M6LA with 447 comments
# ▶️ Starting channel UCllbsv_aoIaPS6W3aSonZlw
# ⚠️ Key exhausted. Switching to key #8/15.
# ⚠️ Key exhausted. Switching to key #8/15.
# ⚠️ Key exhausted. Switching to key #8/15.
# ⚠️ Key exhausted. Switching to key #8/15.
# ✅ Finished channel UCzj9-27Lr4gcqopmZAobXXg with 2125 comments
# ▶️ Starting channel UC2Kfw8fjca8k3w3KpzL5tNg
# ✅ Finished channel UCgaI52w7QKI8LtkSeCCmSuw with 469 comments
# ▶️ Starting channel UCHQm49T6ikD_ioMAt50AwKQ
# ✅ Finished channel UCllbsv_aoIaPS6W3aSonZlw with 87 comments
# ▶️ Starting channel UCYA1psY06vSf3QadHuCrmjQ
# ⏭ No comments for channel UCYA1psY06vSf3QadHuCrmjQ
# ▶️ Starting channel UCPI9ao1Cr1nxEUD2r-usRjQ
# ⏭ No comments for channel UCPI9ao1Cr1nxEUD2r-usRjQ
# ▶️ Starting channel UCnMvVN4a8roZu4crE0UW2DA
# ✅ Finished channel UCnMvVN4a8roZu4crE0UW2DA with 62 comments
# ▶️ Starting channel UCHvf42C8Vw6QnjwO2L2ukKA
# ✅ Finished channel UCpmXOtvvXC3GE8o9VxYNK7g with 16843 comments
# ▶️ Starting channel UCBvOxpqoGi1HlHjX9v_gHZw
# ✅ Finished channel UC2Kfw8fjca8k3w3KpzL5tNg with 2567 comments
# ▶️ Starting channel UCYZfP-cNIvlJY3AcAc9OPpQ
# ✅ Finished channel UCBvOxpqoGi1HlHjX9v_gHZw with 186 comments
# ▶️ Starting channel UCScZcPwdddt6fffxbRLFQVw
# ✅ Finished channel UCYZfP-cNIvlJY3AcAc9OPpQ with 382 comments
# ▶️ Starting channel UCNshPbmupCwP5a7Hi79jETQ
# ✅ Finished channel UCNshPbmupCwP5a7Hi79jETQ with 22 comments
# ▶️ Starting channel UCT8uWroJtkwSsCJlVg0IKvQ
# ✅ Finished channel UCScZcPwdddt6fffxbRLFQVw with 2367 comments
# ▶️ Starting channel UCPVEZgw-VbDRbLV1MRGVQNQ
# ✅ Finished channel UCHvf42C8Vw6QnjwO2L2ukKA with 15989 comments
# ▶️ Starting channel UCnoP3KLT-HOvzDfC1-I-9lQ
# ✅ Finished channel UCnoP3KLT-HOvzDfC1-I-9lQ with 115 comments
# ▶️ Starting channel UCvWY4qKP6--o3pIJY7hhKDg
# ✅ Finished channel UCPVEZgw-VbDRbLV1MRGVQNQ with 14 comments
# ▶️ Starting channel UCZPoYXHFDAV17BGLMzGAmpg
# ✅ Finished channel UCvWY4qKP6--o3pIJY7hhKDg with 283 comments
# ▶️ Starting channel UCMP_Anj7lz4eZuSh8GwFqQQ
# ✅ Finished channel UCT8uWroJtkwSsCJlVg0IKvQ with 640 comments
# ▶️ Starting channel UCxwbFLOlKDsXrwizV5jah7g
# ✅ Finished channel UCxwbFLOlKDsXrwizV5jah7g with 35 comments
# ▶️ Starting channel UC3V7biFZHDFHDFZy6cCSZUA
# ⏭ No comments for channel UCMP_Anj7lz4eZuSh8GwFqQQ
# ▶️ Starting channel UCrxEaX0VKZKwg3930du2D5A
# ✅ Finished channel UCZPoYXHFDAV17BGLMzGAmpg with 344 comments
# ▶️ Starting channel UC9qcJxTqfDNBnVul1IojlFg
# ✅ Finished channel UCrxEaX0VKZKwg3930du2D5A with 180 comments
# ▶️ Starting channel UC5w5qn7nj5Ljy69LTV7a_fQ
# ⚠️ Key exhausted. Switching to key #9/15.
# ⚠️ Key exhausted. Switching to key #9/15.
# ⚠️ Key exhausted. Switching to key #9/15.
# ⚠️ Key exhausted. Switching to key #9/15.
# ✅ Finished channel UC3V7biFZHDFHDFZy6cCSZUA with 1167 comments
# ▶️ Starting channel UCPJGVbOVcAVGiBwq8qr_T9w
# ✅ Finished channel UC5w5qn7nj5Ljy69LTV7a_fQ with 61 comments
# ▶️ Starting channel UCui4k83Cot4aeVW_8T33fgg
# ⏭ No comments for channel UCPJGVbOVcAVGiBwq8qr_T9w
# ▶️ Starting channel UC7kXK_PyDiOT8YrdP0jYZHw
# ✅ Finished channel UCui4k83Cot4aeVW_8T33fgg with 91 comments
# ▶️ Starting channel UCtDrz-8tdg4ZgOAQHToSWaQ
# ✅ Finished channel UC7kXK_PyDiOT8YrdP0jYZHw with 73 comments
# ▶️ Starting channel UCVRbtFwaBGcixZIkygtalRw
# ✅ Finished channel UCtDrz-8tdg4ZgOAQHToSWaQ with 113 comments
# ▶️ Starting channel UChxDE6vho5BfBTOqiBsDmKg
# ✅ Finished channel UCVRbtFwaBGcixZIkygtalRw with 308 comments
# ▶️ Starting channel UCmw-aERG51C96edMDPN7fXQ
# ✅ Finished channel UCmw-aERG51C96edMDPN7fXQ with 11 comments
# ▶️ Starting channel UCRTGfrYP-RuDzJ2KGok7TRA
# ✅ Finished channel UChxDE6vho5BfBTOqiBsDmKg with 231 comments
# ▶️ Starting channel UCqSq9kWOxk9yNTeILBCVC1w
# ✅ Finished channel UCRTGfrYP-RuDzJ2KGok7TRA with 116 comments
# ▶️ Starting channel UCSBgIt02ZoFyfBOgISq77Cw
# ⏭ No comments for channel UC9qcJxTqfDNBnVul1IojlFg
# ▶️ Starting channel UCMzuyZWzk44YRNesFzPTeUw
# ✅ Finished channel UCHQm49T6ikD_ioMAt50AwKQ with 1656 comments
# ▶️ Starting channel UC5H6oYLKQ_xIXO5CG7fh4hw
# ✅ Finished channel UC5H6oYLKQ_xIXO5CG7fh4hw with 5 comments
# ▶️ Starting channel UCr4KOYv1o1oEQhy1jhhm3pQ
# ✅ Finished channel UCMzuyZWzk44YRNesFzPTeUw with 869 comments
# ▶️ Starting channel UC3lif8TFPOe-tJ2-pE4Rp7Q
# ✅ Finished channel UC3lif8TFPOe-tJ2-pE4Rp7Q with 1548 comments
# ▶️ Starting channel UCqzGv_gXgL6xceXQnu5vs3g
# ✅ Finished channel UCqzGv_gXgL6xceXQnu5vs3g with 87 comments
# ▶️ Starting channel UCcJmPR629lPofmQLMBU2xMg
# ✅ Finished channel UCqSq9kWOxk9yNTeILBCVC1w with 2869 comments
# ▶️ Starting channel UCmyD0_-2Oowkfwc_Raghclw
# ✅ Finished channel UCcJmPR629lPofmQLMBU2xMg with 1 comments
# ▶️ Starting channel UCYMNcgHss4_Q5JY2vSvMpgw
# ⚠️ Key exhausted. Switching to key #10/15.
# ⚠️ Key exhausted. Switching to key #10/15.
# ⚠️ Key exhausted. Switching to key #10/15.
# ⚠️ Key exhausted. Switching to key #10/15.
# ✅ Finished channel UCYMNcgHss4_Q5JY2vSvMpgw with 52 comments
# ▶️ Starting channel UCi0niBYFhEY70Dz8InbX5OQ
# ✅ Finished channel UCi0niBYFhEY70Dz8InbX5OQ with 326 comments
# ▶️ Starting channel UCK6U4plOKKMrCjv_h59spGQ
# ✅ Finished channel UCK6U4plOKKMrCjv_h59spGQ with 91 comments
# ▶️ Starting channel UCh9Og3DYZIaIWKriQ3n6cYQ
# ✅ Finished channel UCh9Og3DYZIaIWKriQ3n6cYQ with 53 comments
# ▶️ Starting channel UCKrkKLwcZs7bUehe6ub9Vsg
# ✅ Finished channel UCKrkKLwcZs7bUehe6ub9Vsg with 6 comments
# ▶️ Starting channel UCXRvZ7q1YM__Jyqcbt4aedw
# ✅ Finished channel UCXRvZ7q1YM__Jyqcbt4aedw with 1 comments
# ▶️ Starting channel UCzqBEpeIaDEfvAtsA53Fx2Q
# ✅ Finished channel UCr4KOYv1o1oEQhy1jhhm3pQ with 49141 comments
# ▶️ Starting channel UCIKJJp4QJIDjnjodc23qKkw
# ✅ Finished channel UCIKJJp4QJIDjnjodc23qKkw with 55 comments
# ▶️ Starting channel UCR9abI1lZzAZ6HwQXc-dLFQ
# ✅ Finished channel UCmyD0_-2Oowkfwc_Raghclw with 518 comments
# ▶️ Starting channel UCs5iMvWy-oTHyf5HuwB7FCg
# ✅ Finished channel UCR9abI1lZzAZ6HwQXc-dLFQ with 25 comments
# ▶️ Starting channel UC2clc28qcehIqotHQcthnWA
# ⏭ No comments for channel UC2clc28qcehIqotHQcthnWA
# ▶️ Starting channel UCOmm091WM6D01xTdzsWNvbQ
# ✅ Finished channel UCs5iMvWy-oTHyf5HuwB7FCg with 1702 comments
# ▶️ Starting channel UCVVIZjUpGRB1pgQGDBVBU8Q
# ✅ Finished channel UCVVIZjUpGRB1pgQGDBVBU8Q with 4 comments
# ▶️ Starting channel UCv_kM3OZukHS0rjWpw_JMWg
# ✅ Finished channel UCv_kM3OZukHS0rjWpw_JMWg with 500 comments
# ▶️ Starting channel UCm6vJzx-mu4Xr56FnQKRz0w
# ✅ Finished channel UCm6vJzx-mu4Xr56FnQKRz0w with 20 comments
# ▶️ Starting channel UCQYI19aNR1xdhX2BCkDQSGg
# ✅ Finished channel UCSBgIt02ZoFyfBOgISq77Cw with 90804 comments
# ▶️ Starting channel UCNEpy5bPXiyAavRzYnPlhDQ
# ✅ Finished channel UCQYI19aNR1xdhX2BCkDQSGg with 7 comments
# ▶️ Starting channel UC9XRRGCgGOEtEOwUAo1rYZg
# ✅ Finished channel UCOmm091WM6D01xTdzsWNvbQ with 199 comments
# ▶️ Starting channel UCYFDRohyZgoPy5rXOaVZO-A
# ✅ Finished channel UCNEpy5bPXiyAavRzYnPlhDQ with 935 comments
# ▶️ Starting channel UC2XDiCjAHtJqnSEzrHAY5IQ
# ✅ Finished channel UC9XRRGCgGOEtEOwUAo1rYZg with 614 comments
# ▶️ Starting channel UC46TX2P8K0CA_4gZv8_R2Og
# ⚠️ Key exhausted. Switching to key #11/15.
# ⚠️ Key exhausted. Switching to key #11/15.
# ⚠️ Key exhausted. Switching to key #11/15.
# ⚠️ Key exhausted. Switching to key #11/15.
# ✅ Finished channel UC46TX2P8K0CA_4gZv8_R2Og with 150 comments
# ▶️ Starting channel UCIWDLoDPvawP118TNWi-9rg
# ✅ Finished channel UCIWDLoDPvawP118TNWi-9rg with 31 comments
# ▶️ Starting channel UCx2AS0O5frzPB8D6TqJ3Mqg
# ✅ Finished channel UCYFDRohyZgoPy5rXOaVZO-A with 243 comments
# ▶️ Starting channel UCGydnnhsUZqFBscmcWcT-zQ
# ✅ Finished channel UCGydnnhsUZqFBscmcWcT-zQ with 13 comments
# ▶️ Starting channel UCkhjut8oXdxN7HGg5eRT9Fw
# ✅ Finished channel UCx2AS0O5frzPB8D6TqJ3Mqg with 232 comments
# ▶️ Starting channel UCl5GK07sD5TZIhKcsDNSExA
# ✅ Finished channel UCl5GK07sD5TZIhKcsDNSExA with 408 comments
# ▶️ Starting channel UCsRXg0BmoS4Rkjz-pqX1PmQ
# ✅ Finished channel UCsRXg0BmoS4Rkjz-pqX1PmQ with 387 comments
# ▶️ Starting channel UCXngpVME5LZjcdXxZQxSDQA
# ✅ Finished channel UCXngpVME5LZjcdXxZQxSDQA with 246 comments
# ▶️ Starting channel UCHj4veUyhPzzOW-Jvn7MqUg
# ✅ Finished channel UCkhjut8oXdxN7HGg5eRT9Fw with 30 comments
# ▶️ Starting channel UCuhN60FDf0YWlSqJitl2pvg
# ✅ Finished channel UCHj4veUyhPzzOW-Jvn7MqUg with 53 comments
# ▶️ Starting channel UCAe6fGhotC9J9tR_QONYzFA
# ✅ Finished channel UCAe6fGhotC9J9tR_QONYzFA with 15 comments
# ▶️ Starting channel UCaZ188nNR2eLLem4HnrP_iQ
# ✅ Finished channel UCaZ188nNR2eLLem4HnrP_iQ with 945 comments
# ▶️ Starting channel UCnY3Re6MbG3OtLbLbHOhDcg
# ✅ Finished channel UCuhN60FDf0YWlSqJitl2pvg with 1853 comments
# ▶️ Starting channel UCbE6PJy-4U0DxosEW2TBQRA
# ✅ Finished channel UCbE6PJy-4U0DxosEW2TBQRA with 18 comments
# ▶️ Starting channel UCxeB7xjbLDJM9Yw6brXsX6Q
# ✅ Finished channel UCnY3Re6MbG3OtLbLbHOhDcg with 79 comments
# ▶️ Starting channel UCu9WOwfOSpzNb7Tzahz2ydw
# ✅ Finished channel UCxeB7xjbLDJM9Yw6brXsX6Q with 777 comments
# ▶️ Starting channel UC8bJT16wpa7co50ELvpMTTg
# ✅ Finished channel UCu9WOwfOSpzNb7Tzahz2ydw with 71 comments
# ▶️ Starting channel UC8t0pnbwG7N5z2xHRuFePsA
# ✅ Finished channel UC8t0pnbwG7N5z2xHRuFePsA with 201 comments
# ▶️ Starting channel UCAxs5zhFdAkGbkRnuC3osDw
# ✅ Finished channel UCzqBEpeIaDEfvAtsA53Fx2Q with 87465 comments
# ▶️ Starting channel UCLTp0xAT0gBrF8WReNliMwA
# ✅ Finished channel UCAxs5zhFdAkGbkRnuC3osDw with 817 comments
# ▶️ Starting channel UCL1UGe8cgeicS97LX9EOUHQ
# ✅ Finished channel UCL1UGe8cgeicS97LX9EOUHQ with 5 comments
# ▶️ Starting channel UCy-O5SyyNvoOAZ1ex9z1EXw
# ✅ Finished channel UC8bJT16wpa7co50ELvpMTTg with 23286 comments
# ▶️ Starting channel UC332GOmhxGmHj3WRiHK4hFg
# ✅ Finished channel UCLTp0xAT0gBrF8WReNliMwA with 103 comments
# ▶️ Starting channel UCrNf1uQEmfRZ0Q4G8pTzqfg
# ✅ Finished channel UCrNf1uQEmfRZ0Q4G8pTzqfg with 10 comments
# ▶️ Starting channel UC-o-UOnLuu8pZxZpShG4s7A
# ✅ Finished channel UCy-O5SyyNvoOAZ1ex9z1EXw with 1081 comments
# ▶️ Starting channel UC4NoFq3K8yIGt-LZsxoKlcA
# ✅ Finished channel UC332GOmhxGmHj3WRiHK4hFg with 647 comments
# ▶️ Starting channel UCjy0W7sksMz37IYY27tAZNQ
# ✅ Finished channel UC4NoFq3K8yIGt-LZsxoKlcA with 11 comments
# ▶️ Starting channel UCD-O0Y92UcMglKmoo7BHLsg
# ⚠️ Key exhausted. Switching to key #12/15.
# ⚠️ Key exhausted. Switching to key #12/15.
# ⚠️ Key exhausted. Switching to key #12/15.
# ⚠️ Key exhausted. Switching to key #12/15.
# ✅ Finished channel UCD-O0Y92UcMglKmoo7BHLsg with 362 comments
# ▶️ Starting channel UCc5AGO_bQLeiv313Bbr35fg
# ✅ Finished channel UC-o-UOnLuu8pZxZpShG4s7A with 1914 comments
# ▶️ Starting channel UCp0Ykb-qUGx3ekTH9MIEK-w
# ✅ Finished channel UCp0Ykb-qUGx3ekTH9MIEK-w with 84 comments
# ▶️ Starting channel UCuJFygzYhGiXMZHjhTQy20w
# ✅ Finished channel UC2XDiCjAHtJqnSEzrHAY5IQ with 124118 comments
# ▶️ Starting channel UCMC34yudOdRW3VNzocAlhtw
# ✅ Finished channel UCjy0W7sksMz37IYY27tAZNQ with 2592 comments
# ▶️ Starting channel UCykNfz2jRqmkQjPqLZMUkyw
# ✅ Finished channel UCMC34yudOdRW3VNzocAlhtw with 281 comments
# ▶️ Starting channel UCD329AYGX7YnMMSUaTKWHwA
# ✅ Finished channel UCuJFygzYhGiXMZHjhTQy20w with 404 comments
# ▶️ Starting channel UCseRXy2_n4j97lndfkQ_hAw
# ✅ Finished channel UCseRXy2_n4j97lndfkQ_hAw with 135 comments
# ▶️ Starting channel UCWm1TIf2sX0QHrxlERoh6pw
# ✅ Finished channel UCc5AGO_bQLeiv313Bbr35fg with 20 comments
# ▶️ Starting channel UCGqhocHaJykHufIXBg0sl7g
# ✅ Finished channel UCWm1TIf2sX0QHrxlERoh6pw with 2 comments
# ▶️ Starting channel UCo4paf7SbVdHOi67ayp1DDg
# ✅ Finished channel UCD329AYGX7YnMMSUaTKWHwA with 50 comments
# ▶️ Starting channel UCRYWouIUelEtHYjASOHW4jA
# ✅ Finished channel UCykNfz2jRqmkQjPqLZMUkyw with 166 comments
# ▶️ Starting channel UCU47SDE9H1U5CEqOkviBS5A
# ✅ Finished channel UCGqhocHaJykHufIXBg0sl7g with 27 comments
# ▶️ Starting channel UCcN-bNymt81c6GL1eElRyVg
# ✅ Finished channel UCo4paf7SbVdHOi67ayp1DDg with 160 comments
# ▶️ Starting channel UCXXNWp6uCWiBxlJxkU_zJeQ
# ✅ Finished channel UCU47SDE9H1U5CEqOkviBS5A with 1281 comments
# ▶️ Starting channel UCAenuXjUZagZyD4HQL7_2ZA
# ✅ Finished channel UCAenuXjUZagZyD4HQL7_2ZA with 82 comments
# ▶️ Starting channel UCHcM0qd2GQ2CbOHSGZ06rrA
# ✅ Finished channel UCRYWouIUelEtHYjASOHW4jA with 1266 comments
# ▶️ Starting channel UChlENkILRFCKhRn8Xx2kY1Q
# ✅ Finished channel UChlENkILRFCKhRn8Xx2kY1Q with 12 comments
# ▶️ Starting channel UCBXwZrEZWQiSXebInVuYuvw
# ✅ Finished channel UCBXwZrEZWQiSXebInVuYuvw with 200 comments
# ▶️ Starting channel UC8eb5FpfNeQ1T4GvFNtlpqQ
# ✅ Finished channel UC8eb5FpfNeQ1T4GvFNtlpqQ with 38 comments
# ▶️ Starting channel UCjsRaXe7cnwNoy15ARClqGw
# ✅ Finished channel UCjsRaXe7cnwNoy15ARClqGw with 157 comments
# ▶️ Starting channel UC0IVg3K5cxZw724kyiTrn5w
# ⏭ No comments for channel UC0IVg3K5cxZw724kyiTrn5w
# ▶️ Starting channel UC7XmOqXKLsDirQGS5VDM9OA
# ✅ Finished channel UCcN-bNymt81c6GL1eElRyVg with 1205 comments
# ▶️ Starting channel UCSX3nV53o-1-e0nFA6pPs2w
# ✅ Finished channel UC7XmOqXKLsDirQGS5VDM9OA with 86 comments
# ▶️ Starting channel UCqQJ44qlkVxWV5N12YeacyA
# ✅ Finished channel UCqQJ44qlkVxWV5N12YeacyA with 69 comments
# ▶️ Starting channel UCXgzjVz7TTspLm0OJ1ASyaA
# ✅ Finished channel UCHcM0qd2GQ2CbOHSGZ06rrA with 1156 comments
# ▶️ Starting channel UCnrrkEmvCSPttUPo_44VAHg
# ✅ Finished channel UCSX3nV53o-1-e0nFA6pPs2w with 258 comments
# ▶️ Starting channel UCL7_lHDJZMvztRlQb_RLFfw
# ✅ Finished channel UCXgzjVz7TTspLm0OJ1ASyaA with 500 comments
# ▶️ Starting channel UCYafjxwsbUrWxavqKPY4B-A
# ✅ Finished channel UCL7_lHDJZMvztRlQb_RLFfw with 317 comments
# ▶️ Starting channel UCqHNoy1lbxNZhbMQUuxkb1Q
# ✅ Finished channel UCnrrkEmvCSPttUPo_44VAHg with 1349 comments
# ▶️ Starting channel UCDB-BzTPkdKjZvWLdRa0lUA
# ✅ Finished channel UCXXNWp6uCWiBxlJxkU_zJeQ with 19422 comments
# ▶️ Starting channel UCETJIbCBqsc2x9X1eT7g5bw
# ✅ Finished channel UCETJIbCBqsc2x9X1eT7g5bw with 14 comments
# ▶️ Starting channel UCaEs0pYlL_1cLlPBHfl0RIg
# ✅ Finished channel UCDB-BzTPkdKjZvWLdRa0lUA with 16 comments
# ✅ Finished channel UCqHNoy1lbxNZhbMQUuxkb1Q with 78 comments
# ✅ Finished channel UCaEs0pYlL_1cLlPBHfl0RIg with 178 comments
# ⚠️ Key exhausted. Switching to key #13/15.
# ✅ Finished channel UCYafjxwsbUrWxavqKPY4B-A with 45891 comments

# %%
df_reps_yt_comments = pd.read_csv("reps_youtube_comments_2021_2025.csv", on_bad_lines="warn")

# View the first few rows
df_reps_yt_comments.head()
len(df_reps_yt_comments)
# Out:
# /var/folders/r2/wwj7bwds0239g96hdx5tn0900000gn/T/ipykernel_37074/241888509.py:1: ParserWarning: Skipping line 17522: expected 9 fields, saw 17
#
#   df_reps_yt_comments = pd.read_csv("reps_youtube_comments_2021_2025.csv", on_bad_lines="warn")
# /var/folders/r2/wwj7bwds0239g96hdx5tn0900000gn/T/ipykernel_37074/241888509.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_reps_yt_comments = pd.read_csv("reps_youtube_comments_2021_2025.csv", on_bad_lines="warn")
# 637928

# %%
df_reps_yt_comments["channel_id"].nunique()
# Out:
# 225

# %%
df_reps_yt_comments['channel_id'].value_counts().head()
# Out:
# channel_id
# UC2XDiCjAHtJqnSEzrHAY5IQ    124118
# UCSBgIt02ZoFyfBOgISq77Cw     90804
# UCzqBEpeIaDEfvAtsA53Fx2Q     87465
# UCPFBhS00ivPV585GlnNlyqA     85543
# UCr4KOYv1o1oEQhy1jhhm3pQ     49141
# Name: count, dtype: int64

# %%
df_reps_with_youtube.head()
# Out:
#          first       last id.bioguide current_type current_party  \
# 0  Aumua Amata  Radewagen     R000600          rep    Republican
# 4        Steve     Womack     W000809          rep    Republican
# 5    Frederica     Wilson     W000808          rep      Democrat
# 6       Daniel    Webster     W000806          rep    Republican
# 8       Robert    Wittman     W000804          rep    Republican
#
#   current_state  term_start    term_end      social.youtube  \
# 0            AS  2025-01-03  2027-01-03                 NaN
# 4            AR  2025-01-03  2027-01-03   CongressmanWomack
# 5            FL  2025-01-03  2027-01-03  repfredericawilson
# 6            FL  2025-01-03  2027-01-03       repdanwebster
# 8            VA  2025-01-03  2027-01-03          RobWittman
#
#           social.youtube_id   social.twitter  social.twitter_id  \
# 0  UCGdrLQbt1PYDTPsampx4t1A         RepAmata       3.026623e+09
# 4  UCXJbUDLYX-wGIhRuN66hqZw  Rep_SteveWomack       2.344693e+08
# 5  UCP5QBhng_lHv-vJgE_h7lpA        RepWilson       2.340141e+08
# 6  UCCoX4VdU7U11eGEA0lbRtLw       RepWebster       2.815407e+08
# 8  UCIqIb-OaTbkIdU426eYIdPg       RobWittman       1.535641e+07
#
#   social.instagram  social.instagram_id social.facebook  \
# 0              NaN                  NaN      aumuaamata
# 4  rep_stevewomack                  NaN  RepSteveWomack
# 5        repwilson                  NaN       RepWilson
# 6              NaN                  NaN      RepWebster
# 8    reprobwittman                  NaN   RepRobWittman
#
#                                          youtube_url
# 0  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 4  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 5  https://www.youtube.com/channel/UCP5QBhng_lHv-...
# 6  https://www.youtube.com/channel/UCCoX4VdU7U11e...
# 8  https://www.youtube.com/channel/UCIqIb-OaTbkId...

# %%
df_reps_with_youtube = df_reps_with_youtube.rename(columns={"social.youtube_id": "channel_id"})



df_reps_with_youtube.columns
# Out:
# Index(['first', 'last', 'id.bioguide', 'current_type', 'current_party',
#        'current_state', 'term_start', 'term_end', 'social.youtube',
#        'channel_id', 'social.twitter', 'social.twitter_id', 'social.instagram',
#        'social.instagram_id', 'social.facebook', 'youtube_url'],
#       dtype='object')

# %%
df_reps_yt_comments.head()
# Out:
#                  channel_id     video_id                  comment_id  \
# 0  UCGdrLQbt1PYDTPsampx4t1A  Zod1WBrDViU  UgyFy--3BW_ZRQMNk3V4AaABAg
# 1  UCGdrLQbt1PYDTPsampx4t1A  Zod1WBrDViU  UgxOq-IZP5npb09Wxv14AaABAg
# 2  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  Ugwr0YkkCsMK9Z7ULHt4AaABAg
# 3  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  UgxLfWhhiGd1VpF_V9N4AaABAg
# 4  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  UgzToKNUidyAtuhTJKJ4AaABAg
#
#              author                                               text  \
# 0  @hasaneurope4603                                                NaN
# 1  @hasaneurope4603                                             ❤❤💛💛🤍🤍
# 2          @eddoura  Mr.Kermit Womack was a GIANT towering figure. ...
# 3      @Bluefrog247  I will greatly miss listening to your father e...
# 4      @djaztec9075  Today was a sad day in broadcasting. I'm grate...
#
#            published_at is_reply parent_id Unnamed: 8
# 0  2023-09-10T11:36:08Z    FALSE       NaN        NaN
# 1  2023-09-10T11:35:58Z    FALSE       NaN        NaN
# 2  2024-10-11T23:14:24Z    FALSE       NaN        NaN
# 3  2024-07-03T01:58:59Z    FALSE       NaN        NaN
# 4  2024-07-01T22:51:10Z    FALSE       NaN        NaN

# %%
#merge comments df with reps info dfs
cols_to_keep = ['first', 'last', 'id.bioguide', 'current_type', 'current_party',
       'current_state', 'term_start', 'term_end', 'social.youtube',
       'channel_id', 'youtube_url']

df_reps_yt_comments_complete = df_reps_yt_comments.merge(
    df_reps_with_youtube[cols_to_keep],
    on="channel_id",
    how="left"
)
df_reps_yt_comments_complete.head()
# Out:
#                  channel_id     video_id                  comment_id  \
# 0  UCGdrLQbt1PYDTPsampx4t1A  Zod1WBrDViU  UgyFy--3BW_ZRQMNk3V4AaABAg
# 1  UCGdrLQbt1PYDTPsampx4t1A  Zod1WBrDViU  UgxOq-IZP5npb09Wxv14AaABAg
# 2  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  Ugwr0YkkCsMK9Z7ULHt4AaABAg
# 3  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  UgxLfWhhiGd1VpF_V9N4AaABAg
# 4  UCXJbUDLYX-wGIhRuN66hqZw  BI4_jtPh67M  UgzToKNUidyAtuhTJKJ4AaABAg
#
#              author                                               text  \
# 0  @hasaneurope4603                                                NaN
# 1  @hasaneurope4603                                             ❤❤💛💛🤍🤍
# 2          @eddoura  Mr.Kermit Womack was a GIANT towering figure. ...
# 3      @Bluefrog247  I will greatly miss listening to your father e...
# 4      @djaztec9075  Today was a sad day in broadcasting. I'm grate...
#
#            published_at is_reply parent_id Unnamed: 8        first       last  \
# 0  2023-09-10T11:36:08Z    FALSE       NaN        NaN  Aumua Amata  Radewagen
# 1  2023-09-10T11:35:58Z    FALSE       NaN        NaN  Aumua Amata  Radewagen
# 2  2024-10-11T23:14:24Z    FALSE       NaN        NaN        Steve     Womack
# 3  2024-07-03T01:58:59Z    FALSE       NaN        NaN        Steve     Womack
# 4  2024-07-01T22:51:10Z    FALSE       NaN        NaN        Steve     Womack
#
#   id.bioguide current_type current_party current_state  term_start  \
# 0     R000600          rep    Republican            AS  2025-01-03
# 1     R000600          rep    Republican            AS  2025-01-03
# 2     W000809          rep    Republican            AR  2025-01-03
# 3     W000809          rep    Republican            AR  2025-01-03
# 4     W000809          rep    Republican            AR  2025-01-03
#
#      term_end     social.youtube  \
# 0  2027-01-03                NaN
# 1  2027-01-03                NaN
# 2  2027-01-03  CongressmanWomack
# 3  2027-01-03  CongressmanWomack
# 4  2027-01-03  CongressmanWomack
#
#                                          youtube_url
# 0  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 1  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 2  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 3  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 4  https://www.youtube.com/channel/UCXJbUDLYX-wGI...

# %%
#rename columns
df_reps_yt_comments_complete = df_reps_yt_comments_complete.rename(columns={'first' : 'rep.first_name', 'last':'rep.last_name', 'id.bioguide' : 'rep.id_bioguide', 'current_type' : 'rep_chamber', 'current_party':'rep_party',
       'current_state':'rep_state'})
df_reps_yt_comments_complete.columns
# Out:
# Index(['channel_id', 'video_id', 'comment_id', 'author', 'text',
#        'published_at', 'is_reply', 'parent_id', 'Unnamed: 8', 'rep.first_name',
#        'rep.last_name', 'rep.id_bioguide', 'rep_chamber', 'rep_party',
#        'rep_state', 'term_start', 'term_end', 'social.youtube', 'youtube_url'],
#       dtype='object')

# %%
new_order = ['rep.first_name',
       'rep.last_name', 'rep.id_bioguide', 'rep_chamber', 'rep_party',
       'rep_state', 'term_start', 'term_end','channel_id','social.youtube', 'youtube_url', 'video_id', 'comment_id', 'author', 'text',
       'published_at', 'is_reply', 'parent_id']

df_reps_yt_comments_complete = df_reps_yt_comments_complete[new_order]

df_reps_yt_comments_complete.head()
# Out:
#   rep.first_name rep.last_name rep.id_bioguide rep_chamber   rep_party  \
# 0    Aumua Amata     Radewagen         R000600         rep  Republican
# 1    Aumua Amata     Radewagen         R000600         rep  Republican
# 2          Steve        Womack         W000809         rep  Republican
# 3          Steve        Womack         W000809         rep  Republican
# 4          Steve        Womack         W000809         rep  Republican
#
#   rep_state  term_start    term_end                channel_id  \
# 0        AS  2025-01-03  2027-01-03  UCGdrLQbt1PYDTPsampx4t1A
# 1        AS  2025-01-03  2027-01-03  UCGdrLQbt1PYDTPsampx4t1A
# 2        AR  2025-01-03  2027-01-03  UCXJbUDLYX-wGIhRuN66hqZw
# 3        AR  2025-01-03  2027-01-03  UCXJbUDLYX-wGIhRuN66hqZw
# 4        AR  2025-01-03  2027-01-03  UCXJbUDLYX-wGIhRuN66hqZw
#
#       social.youtube                                        youtube_url  \
# 0                NaN  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 1                NaN  https://www.youtube.com/channel/UCGdrLQbt1PYDT...
# 2  CongressmanWomack  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 3  CongressmanWomack  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
# 4  CongressmanWomack  https://www.youtube.com/channel/UCXJbUDLYX-wGI...
#
#       video_id                  comment_id            author  \
# 0  Zod1WBrDViU  UgyFy--3BW_ZRQMNk3V4AaABAg  @hasaneurope4603
# 1  Zod1WBrDViU  UgxOq-IZP5npb09Wxv14AaABAg  @hasaneurope4603
# 2  BI4_jtPh67M  Ugwr0YkkCsMK9Z7ULHt4AaABAg          @eddoura
# 3  BI4_jtPh67M  UgxLfWhhiGd1VpF_V9N4AaABAg      @Bluefrog247
# 4  BI4_jtPh67M  UgzToKNUidyAtuhTJKJ4AaABAg      @djaztec9075
#
#                                                 text          published_at  \
# 0                                                NaN  2023-09-10T11:36:08Z
# 1                                             ❤❤💛💛🤍🤍  2023-09-10T11:35:58Z
# 2  Mr.Kermit Womack was a GIANT towering figure. ...  2024-10-11T23:14:24Z
# 3  I will greatly miss listening to your father e...  2024-07-03T01:58:59Z
# 4  Today was a sad day in broadcasting. I'm grate...  2024-07-01T22:51:10Z
#
#   is_reply parent_id
# 0    FALSE       NaN
# 1    FALSE       NaN
# 2    FALSE       NaN
# 3    FALSE       NaN
# 4    FALSE       NaN

# %%
df_reps_yt_comments_complete.to_csv("clean_data/df_reps_yt_comments_complete.csv", index=False)
